# %%
rules = {
    "hello": "Hi there! How can I help?",
    "bye": "Goodbye! Have a great day.",
    "help": "I can respond to hello, bye, or help.",
    "thanks": "You're welcome!"
}

def reflex_agent(user_input):
  user_input=user_input.lower()

  if user_input in rules:
    return rules[user_input]
  else:
    return "I don't understand what you are expecting."

print("Reflex Agent Ready. Type 'hello', 'help', 'bye', 'thanks' or 'exit' to stop.")

while True:
  user_input = input("You: ").lower()

  if user_input == "exit":
    print("Agent: Shutting down.")
    break

  print("Agent: ", reflex_agent(user_input))
# Out:
# Reflex Agent Ready. Type 'hello', 'help', 'bye', 'thanks' or 'exit' to stop.
# You: hello
# Agent:  Hi there! How can I help?
# You: help
# Agent:  I can respond to hello, bye, or help.
# You: THANKS
# Agent:  You're welcome!
# You: bye
# Agent:  Goodbye! Have a great day.
# You: Exit
# Agent: Shutting down.
