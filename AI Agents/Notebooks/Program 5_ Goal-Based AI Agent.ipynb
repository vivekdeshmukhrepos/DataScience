# %%
goals_actions = {
    "get fit": "You should try regular exercise and a healthy diet.",
    "learn python": "Start with basics like variables, loops, and functions.",
    "save money": "Track your expenses and make a monthly budget.",
    "improve sleep": "Avoid screens before bed and maintain a routine."
}

def goal_base_agent(user_input):
  user_input=user_input.lower()

  for goal,advice in goals_actions.items():
    if goal in user_input:
      return f"Goals recognised: '{goal}'. Suggestion: {advice}"

  return "Sorry, I could not find matching goal. Try saying 'I want to get fit' or 'I want to learn Python'."

print("Goal-Based Agent: Tell me your goal. Example: 'I want to get fit'. Type 'exit' to stop.")

while True:
  user_input = input("You: ").lower()

  if user_input == "exit":
    print("Agent: Shutting down.")
    break

  print("Agent: ", goal_base_agent(user_input))
# Out:
# Goal-Based Agent: Tell me your goal. Example: 'I want to get fit'. Type 'exit' to stop.
# You: I want to be fit
# Agent:  Sorry, I could not find matching goal. Try saying 'I want to get fit' or 'I want to learn Python'.
# You: I want to get fit
# Agent:  Goals recognised: 'get fit'. Suggestion: You should try regular exercise and a healthy diet.
# You: I want to improve sleep
# Agent:  Goals recognised: 'improve sleep'. Suggestion: Avoid screens before bed and maintain a routine.
# You: exit
# Agent: Shutting down.
