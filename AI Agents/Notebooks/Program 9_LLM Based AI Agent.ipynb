# %%
from google.colab import drive
drive_path = '/content/drive'
drive.mount(drive_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json

secret_file_path = "/content/drive/My Drive/Secret_Keys/OpenAI_Secret_Key.json"

with open(secret_file_path, "r") as f:
  data=json.load(f)

secret_Key = data["open_ai_key"]

# %%
# Install OpenAI if not already done
# !pip install openai --quiet

# %%
import openai
from openai import OpenAI

client= OpenAI(api_key=secret_Key)

# %%
def chat_agent(prompt):
  try:
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages= [
                {"role": "system", "content": "You are a helpful assistant AI agent."},
                {"role": "user", "content": prompt}
        ]
    )

    return response.choices[0].message.content.strip()
  except Exception as e:
    return f"Error from LLM:{e}"

# %%
print ("Chat Agent . Type 'exit' to stop.")

while True:
  user_input = input("You: ").lower()

  if user_input == "exit":
    print("Agent: Shutting down.")
    break

  print("Agent: ", chat_agent(user_input))
# Out:
# Chat Agent . Type 'exit' to stop.
# You: How can I get open ai key?
# Agent:  To obtain an OpenAI API key, follow these steps:
#
# 1. **Sign Up for an Account:**
#    - Visit the [OpenAI website](https://www.openai.com/) and create an account if you don't already have one. You may need to provide some basic information and verify your email address.
#
# 2. **Access the API Section:**
#    - Once logged in, navigate to the API section of the website. This is usually found in the dashboard or a menu related to developers.
#
# 3. **Create an API Key:**
#    - In the API section, you should find an option to create a new API key. Click on that option and follow the prompts. You might need to agree to some terms of service.
#
# 4. **Copy and Save Your API Key:**
#    - After generating the key, make sure to copy it and store it securely. Treat it like a password; do not share it publicly as it can grant access to your OpenAI account.
#
# 5. **Review Usage and Billing:**
# ...
